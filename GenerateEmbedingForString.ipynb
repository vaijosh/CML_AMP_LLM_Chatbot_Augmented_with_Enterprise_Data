# %%
import executeHbasecommand as executeHbasecommand
executeHbasecommand.run_hbase_commands(list)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-5-7cd163757c03> in <module>()
#       1 import executeHbasecommand as executeHbasecommand
# ----> 2 executeHbasecommand.run_hbase_commands(list)
#
# /Users/vjoshi/DevNotes/HACKATHON-2023/CML_AMP_LLM_Chatbot_Augmented_with_Enterprise_Data/executeHbasecommand.pyc in run_hbase_commands(command_name)
#       6   ssh = paramiko.SSHClient()
#       7   ssh.set_missing_host_key_policy(paramiko.AutoAddPolicy())
# ----> 8   ssh.connect(hostname=host, username="root", key_filename=key_pair)
#       9   print("--> Connected")
#      10
#
# ...

# %%
# put some document

# %%
# get embedding for query
import utils.model_embedding_utils as model_embedding_utils
embeddings =  model_embedding_utils.get_embeddings("Artificial intelligence")
print(embeddings)
# Out:
# [-0.04259272664785385, 0.019875166937708855, -0.013642219826579094, 0.0277074184268713, -0.06550540775060654, -0.07933696359395981, 0.07689300924539566, 0.012388107366859913, 0.028604937717318535, 0.05810244381427765, 0.0377744622528553, 0.035147834569215775, -0.017195144668221474, 2.2267848180490546e-05, -0.03810939937829971, 0.018250441178679466, 0.02817668206989765, 0.0387609526515007, -0.046510715037584305, -0.11838347464799881, -0.008997560478746891, 0.01993347890675068, -0.04029810428619385, 0.008723344653844833, -0.0637044757604599, -0.012400581501424313, 0.04888089373707771, 0.10084708780050278, -0.015582414343953133, -0.09391546249389648, -0.025998283177614212, -0.015725677832961082, 0.13608147203922272, 0.01994779147207737, 0.01565677300095558, -0.014111263677477837, 0.012764769606292248, 0.02054928056895733, -0.030249405652284622, 0.006366327404975891, -0.04751010239124298, -0.11902099847793579, -0.007297249510884285, 0.08335055410861969, 0.04135086014866829, -0.0457228757
# ...

# %%
scan Filter <ebmeddig>

# %%
get rowid

# %%
print file using filename
